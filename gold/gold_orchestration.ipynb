# %% [markdown]
# ###GOLD ORCHESTRATION
#
# This notebook orchestrates all Gold layer notebooks.
# It builds business-ready dimension and fact tables for analytics.

# %%
# List of Gold notebooks to run in sequence
gold_notebooks = [
    "gold/gold_dim_customers",
    "gold/gold_dim_products",
    "gold/gold_fact_sales"
]

# Run each Gold notebook sequentially
for notebook in gold_notebooks:
    print(f"Running notebook: {notebook}")
    dbutils.notebook.run(
        f"/Workspace/Users/argjendazabergja@gmail.com/Databricks-Bootcamp/{notebook}",
        timeout_seconds=0
    )
